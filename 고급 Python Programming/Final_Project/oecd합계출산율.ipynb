# %%
import pandas as pd

# %%
df_oecd=pd.read_csv('./oecd.csv',encoding='cp949')

# %%
df_oecd.shape
# Out:
# (37, 6)

# %%
df_oecd
# Out:
#         국가별  2000  2005  2010  2015  2020
# 0        한국  1.50  1.21  1.17  1.23  1.11
# 1      이스라엘  2.93  2.91  2.93  3.04  3.04
# 2        일본  1.37  1.30  1.34  1.41  1.37
# 3        터키  2.65  2.37  2.20  2.12  2.08
# 4       캐나다  1.56  1.52  1.64  1.60  1.53
# 5       멕시코  2.85  2.61  2.40  2.29  2.14
# 6        미국  2.00  2.04  2.06  1.88  1.78
# 7        칠레  2.20  1.95  1.90  1.85  1.65
# 8      콜롬비아  2.70  2.44  2.10  1.92  1.82
# 9     오스트리아  1.39  1.38  1.40  1.45  1.53
# 10      벨기에  1.60  1.68  1.82  1.78  1.71
# 11       체코  1.17  1.19  1.43  1.48  1.64
# 12      덴마크  1.76  1.76  1.85  1.73  1.76
# 13    에스토니아  1.33  1.39  1.66  1.59  1.59
# 14      핀란드  1.74  1.75  1.84  1.77  1.53
# 15      프랑스  1.76  1.88  1.98  1.98  1.85
# 16       독일  1.35  1.35  1.36  1.43  1.59
# 17      그리스  1.31  1.29  1.42  1.34  1.30
# 18      헝가리  1.38  1.30  1.33  1.33  1.49
# 19    아이슬란드  2.06  1.99  2.13  1.98  1.77
# 20     아일랜드  1.90  1.93  2.00  1.97  1.84
# ...

# %%
df=df_oecd.melt(id_vars='국가별',var_name='연도',value_name='출산율')

# %%
df.head()
# Out:
#     국가별    연도   출산율
# 0    한국  2000  1.50
# 1  이스라엘  2000  2.93
# 2    일본  2000  1.37
# 3    터키  2000  2.65
# 4   캐나다  2000  1.56

# %%
df['국가별'].unique()
# Out:
# array(['한국', '이스라엘', '일본', '터키', '캐나다', '멕시코', '미국', '칠레', '콜롬비아',
#        '오스트리아', '벨기에', '체코', '덴마크', '에스토니아', '핀란드', '프랑스', '독일', '그리스',
#        '헝가리', '아이슬란드', '아일랜드', '이탈리아', '라트비아', '리투아니아', '룩셈부르크', '네덜란드',
#        '노르웨이', '폴란드', '포르투갈', '슬로바키아', '슬로베니아', '스페인', '스웨덴', '스위스', '영국',
#        '오스트레일리아', '뉴질랜드'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국가별     185 non-null    object
#  1   연도      185 non-null    object
#  2   출산율     185 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 4.5+ KB

# %%
df['출산율'].describe()
# Out:
# count    185.000000
# mean       1.689135
# std        0.385972
# min        1.110000
# 25%        1.400000
# 50%        1.640000
# 75%        1.880000
# max        3.040000
# Name: 출산율, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font",family="AppleGothic")

# %%
plt.figure(figsize=(18,17))
sns.lineplot(data=df,x="연도",y="출산율",hue="국가별")
plt.legend(loc='center right',bbox_to_anchor=(1.13,0.6),ncol=1)

# %%
df_local=df[df['국가별'].isin(['한국','이스라엘','일본'])]

# %%
df_local.head()
# Out:
#      국가별    연도   출산율
# 0     한국  2000  1.50
# 1   이스라엘  2000  2.93
# 2     일본  2000  1.37
# 37    한국  2005  1.21
# 38  이스라엘  2005  2.91

# %%
import numpy as np
sns.lineplot(data=df_local,x="연도",y="출산율",hue="국가별")

# %%
df_israel
# Out:
#       국가별    연도   출산율
# 1    이스라엘  2000  2.93
# 38   이스라엘  2005  2.91
# 75   이스라엘  2010  2.93
# 112  이스라엘  2015  3.04
# 149  이스라엘  2020  3.04

# %%
import numpy as np
sns.lineplot(data=df_israel,x="연도",y="출산율")
